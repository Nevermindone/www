# %%
import pandas as pd
import numpy as np

# %%
def float_handle(dff):
    dff['LotAreaAdditional']=dff['LotAreaAdditional'].fillna(0)
    dff=dff.drop('YearReconstruction',axis=1)
    dff=dff.drop('Variable01',axis=1)
    dff=dff.drop('Variable02',axis=1)
    dff=dff.drop('Variable03',axis=1)
    dff=dff.drop('Variable04',axis=1)
    dff['3rdFlrSF']=dff['3rdFlrSF'].fillna(0)
    dff['LotFrontage']=dff['LotFrontage'].fillna(0)
    dff['GarageYrBlt']=dff['GarageYrBlt'].fillna(min(df['GarageYrBlt']))
    dff['MasVnrArea']=dff['MasVnrArea'].fillna(0)
    return dff

# %%
def years_to_age(dff):
    dff['YearBuilt']=dff['YearBuilt'].apply(lambda x: 2010-x)
    dff['YearRemodAdd']=dff['YearRemodAdd'].apply(lambda x: 2010-x)
    dff['GarageYrBlt']=dff['GarageYrBlt'].apply(lambda x: 2010-x)
    dff['YrSold']=dff['YrSold'].apply(lambda x: 2010-x)
    return dff

# %%
pd.set_option('display.max_rows', 500)

# %%
df=pd.read_csv(r'C:\Users\Администратор\Desktop\REAskills2021\train.csv')

# %%
df=df.drop('Unnamed: 0', axis=1)

# %%
# list_val=[1241 for x in range(88)]

# %%
df=float_handle(df)

# %%
list_val=[1241 for x in range(88)]
list_percentage=[]
nans=df.isna().sum().tolist()
for i in range(len(nans)):
    list_percentage.append(nans[i]/list_val[i]*100)
df_perc=pd.DataFrame([list_percentage,list(df.columns.values),df.dtypes.values.tolist()])    
df_perc=df_perc.T.rename(columns={0: "percents", 1: "cols",2:'dtype'})
df_perc.sort_values(by=['percents'],ascending=False)
# Out:
#     percents               cols    dtype
# 61  5.318292         GarageQual   object
# 58  5.318292       GarageFinish   object
# 56  5.318292         GarageType   object
# 31  2.497985       BsmtFinType1   object
# 28  2.497985           BsmtQual   object
# 29  2.497985           BsmtCond   object
# 33  2.497985       BsmtFinType2   object
# 50       0.0       KitchenAbvGr    int64
# 51       0.0        KitchenQual   object
# 52       0.0       TotRmsAbvGrd    int64
# 60       0.0         GarageArea    int64
# 53       0.0         Functional   object
# 49       0.0       BedroomAbvGr    int64
# 54       0.0         Fireplaces    int64
# 48       0.0           HalfBath    int64
# 47       0.0           FullBath    int64
# 55       0.0        FireplaceQu   object
# 46       0.0       BsmtHalfBath    int64
# 57       0.0        GarageYrBlt  float64
# 45       0.0       BsmtFullBath    int64
# 59       0.0         GarageCars    int64
# 0        0.0         MSSubClass    int64
# 43       0.0       LowQualFinSF    int64
# 72       0.0        MiscFeature   object
# 80       0.0           3rdFlrSF  float64
# 79       0.0  LotAreaAdditional  float64
# 78       0.0          SalePrice    int64
# 77       0.0      SaleCondition   object
# 76       0.0           SaleType   object
# 75       0.0             YrSold    int64
# 74       0.0             MoSold    int64
# 73       0.0            MiscVal    int64
# 71       0.0              Fence   object
# 62       0.0         GarageCond   object
# 70       0.0             PoolQC   object
# 69       0.0           PoolArea    int64
# 68       0.0        ScreenPorch    int64
# 67       0.0          3SsnPorch    int64
# 66       0.0      EnclosedPorch    int64
# 65       0.0        OpenPorchSF    int64
# 64       0.0         WoodDeckSF    int64
# 63       0.0         PavedDrive   object
# 44       0.0          GrLivArea    int64
# 41       0.0           1stFlrSF    int64
# 42       0.0           2ndFlrSF    int64
# 10       0.0          LandSlope   object
# 17       0.0          YearBuilt    int64
# 16       0.0        OverallCond    int64
# 15       0.0         HouseStyle   object
# 14       0.0           BldgType   object
# 13       0.0         Condition2   object
# 12       0.0         Condition1   object
# 11       0.0       Neighborhood   object
# 9        0.0          LotConfig   object
# 1        0.0           MSZoning   object
# 8        0.0          Utilities   object
# 7        0.0        LandContour   object
# 6        0.0           LotShape   object
# 5        0.0              Alley   object
# 4        0.0             Street   object
# 3        0.0            LotArea    int64
# 2        0.0        LotFrontage  float64
# 18       0.0       YearRemodAdd    int64
# 19       0.0          RoofStyle   object
# 20       0.0           RoofMatl   object
# 21       0.0        Exterior1st   object
# 40       0.0         Electrical   object
# 39       0.0         CentralAir   object
# 38       0.0          HeatingQC   object
# 37       0.0            Heating   object
# 36       0.0        TotalBsmtSF    int64
# 35       0.0          BsmtUnfSF    int64
# 34       0.0         BsmtFinSF2    int64
# 32       0.0         BsmtFinSF1    int64
# 30       0.0       BsmtExposure   object
# 27       0.0         Foundation   object
# 26       0.0          ExterCond   object
# 25       0.0          ExterQual   object
# 24       0.0         MasVnrArea  float64
# 23       0.0         MasVnrType   object
# 22       0.0        Exterior2nd   object
# 81       0.0         Variable05    int64
# ERROR! Session/line number was not unique in database. History logging moved to new session 10

# %%
df['PoolQC']=df['PoolQC'].fillna('No Pool')

# %%
df['MiscFeature']=df['MiscFeature'].fillna('noAdd')

# %%
df['Alley']=df['Alley'].fillna('NoAccess')

# %%
df['Fence']=df['Fence'].fillna('NoFence')

# %%
df['FireplaceQu']=df['FireplaceQu'].fillna('NoFireplace')

# %%
df['GarageCond']=df['GarageCond'].fillna('noG')

# %%
df['BsmtExposure']=df['BsmtExposure'].fillna('NoB')

# %%
df['MasVnrType']=df['MasVnrType'].fillna('noM')

# %%
def most_common(lst):
    return max(set(lst), key=lst.count)
df['Electrical']=df['Electrical'].fillna(most_common(df['Electrical'].tolist()))

# %%
df['OverallQual']=df['OverallQual'].astype('str').apply(lambda x: ''.join([i for i in x if i not in '!"#$%&\'()*+,-./:;<=>?@[\\]^`{|}~']) )
df['OverallQual']=df['OverallQual'].astype('float')
popped=df.pop('OverallQual')

# %%
df_obj=df.select_dtypes(include=['object'])

# %%
df_obj=pd.get_dummies(df_obj,drop_first=True)

# %%
# df_ok=df.select_dtypes(include=['float64','int64'])
df_ok=df.select_dtypes(include=['int64'])

# %%
df_1=pd.concat([df_ok,df_obj], axis=1)
# df_1=years_to_age(df_1)

# %%
SalePrice=df_1.pop('SalePrice')

# %%
Y=SalePrice.values.tolist()

# %%
from sklearn.model_selection import train_test_split
df_1['OverallQual']=popped
df_1['OverallQual']=df_1['OverallQual'].fillna(123)
df2=df_1.loc[df_1['OverallQual']!=123]
df3=df_1.loc[df_1['OverallQual']==123]

y=df2.pop('OverallQual')
X_train, X_test, y_train, y_test = train_test_split(df2, y, test_size=0.25, random_state=42)

from sklearn.ensemble import RandomForestClassifier
regr = RandomForestClassifier()
regr.fit(df2, y)
from sklearn.metrics import accuracy_score
df3.pop('OverallQual')
predictions=regr.predict(df3)
df2['OverallQual']=y
df3['OverallQual']=predictions.tolist()
df_1=pd.concat([df2,df3],axis=0)
df_1.sort_index(inplace=True)
# Out:
# <ipython-input-26-af07a516b89a>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['OverallQual']=y
# <ipython-input-26-af07a516b89a>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['OverallQual']=predictions.tolist()

# %% [markdown]
# <h1>ОБУЧЕНИЕ</h1>

# %%
from sklearn.linear_model import LinearRegression

X_train, X_test, y_train, y_test = train_test_split(df_1, Y, test_size=0.25, random_state=42)
regr = LinearRegression()
regr.fit(X_train, y_train)
from sklearn.metrics import r2_score
predictions=regr.predict(X_test)
r2_score(y_test,predictions)
# Out:
# 0.0006064606701471353

# %%
X_train, X_test, y_train, y_test = train_test_split(df_1, Y, test_size=0.25, random_state=42)

from sklearn.linear_model import Ridge
regr = Ridge()
regr.fit(X_train, y_train)
from sklearn.metrics import r2_score
predictions=regr.predict(X_test)
r2_score(y_test,predictions)
# Out:
# 0.8669724159668921

# %%
from sklearn import linear_model
X_train, X_test, y_train, y_test = train_test_split(df_1, Y, test_size=0.25, random_state=42)

from sklearn.linear_model import Ridge
regr = linear_model.Ridge()
regr.fit(X_train, y_train)
from sklearn.metrics import r2_score
predictions=regr.predict(X_test)
r2_score(y_test,predictions)
# Out:
# 0.8669724159668921

# %%
from sklearn.model_selection import cross_val_score

# %%
regr = linear_model.Ridge()
scores = cross_val_score(regr, df_1, Y, cv=5,scoring='r2')

# %%
print("%0.2f accuracy with a standard deviation of %0.2f" % (scores.mean(), scores.std()))
# Out:
# 0.80 accuracy with a standard deviation of 0.09

# %%
import xgboost as xgb

# %%
# df_1.pop('OverallQual')
X_train, X_test, y_train, y_test = train_test_split(df_1, Y, test_size=0.25, random_state=42)

xgbr = xgb.XGBRegressor(verbosity=0) 
xgbr.fit(X_train, y_train)
from sklearn.metrics import r2_score
predictions=xgbr.predict(X_test)
r2_score(y_test,predictions)
# 0.8680607142086648
# 0.8645130477489023
# 0.881600011517741
# Out:
# c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# 0.8819654232918865

# %%
scores = cross_val_score(xgbr, df_1, Y, cv=5,scoring='r2')
# Out:
# c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(

# %%
print("%0.2f accuracy with a standard deviation of %0.2f" % (scores.mean(), scores.std()))
# Out:
# 0.83 accuracy with a standard deviation of 0.03

# %%
# %%time
cross_val_score(xgbr, df_1, Y, cv=5,scoring='r2')

# array([0.74853435, 0.77426844, 0.79585604, 0.82154976, 0.88967844])
# Out:
# c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# Wall time: 2.02 s
# c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# array([0.81318038, 0.79328634, 0.81738827, 0.86870353, 0.85301814])

# %%
# df_1['OverallQual']=popped
# df_1['OverallQual']
# df_1['OverallQual']=df_1['OverallQual'].fillna(123)

# %%
# %%time
import xgboost as xgb
from sklearn.model_selection import GridSearchCV

parameters = { 
                        'objective':['reg:linear'],
                      'learning_rate': [0.3,0.2,0.1], 
                      'max_depth': [4,5,6],
                      'min_child_weight': [1,2,3],
                      'silent': [1],
                      'subsample': [0.5,0.6,0.7],
                      'colsample_bytree': [0.7,0.8,0.85],
                      'n_estimators': [100,200,300]}
# parameters = { 
#                     'objective':['reg:linear'],
#                     'learning_rate': [0.3], 
#                     'max_depth': [4],
#                     'min_child_weight': [1],
#                     'silent': [1],
#                     'subsample': [0.5],
#                     'colsample_bytree': [0.7],
#                     'n_estimators': [100]}
xgb1 = xgb.XGBRegressor(verbosity=0) 


xgb_grid = GridSearchCV(xgb1,
                        parameters,
                        scoring='r2', #this line can be commented to use XGB's default metric
                        cv = 5,
                        n_jobs = 5,
                        verbose=True)


xgb_grid.fit(df_1,Y)
# Out:
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\joblib\parallel.py", line 933, in retrieve
#     self._output.extend(job.get(timeout=self.timeout))
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\joblib\_parallel_backends.py", line 542, in wrap_future_result
#     return future.result(timeout=timeout)
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\concurrent\futures\_base.py", line 435, in result
#     self._condition.wait(timeout)
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\threading.py", line 312, in wait
#     waiter.acquire()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\magics\execution.py", line 1326, in time
#     out = eval(code_2, glob, local_ns)
#   File "<timed exec>", line 33, in <module>
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\sklearn\model_selection\_search.py", line 841, in fit
#     self._run_search(evaluate_candidates)
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\sklearn\model_selection\_search.py", line 1288, in _run_search
#     evaluate_candidates(ParameterGrid(self.param_grid))
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\sklearn\model_selection\_search.py", line 795, in evaluate_candidates
#     out = parallel(delayed(_fit_and_score)(clone(base_estimator),
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\joblib\parallel.py", line 1054, in __call__
#     self.retrieve()
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\joblib\parallel.py", line 955, in retrieve
#     backend.abort_everything(ensure_ready=ensure_ready)
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\joblib\_parallel_backends.py", line 561, in abort_everything
#     self._workers.terminate(kill_workers=True)
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\joblib\executor.py", line 74, in terminate
#     self.shutdown(kill_workers=kill_workers)
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\joblib\externals\loky\process_executor.py", line 1171, in shutdown
#     executor_manager_thread.join()
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\threading.py", line 1033, in join
#     self._wait_for_tstate_lock()
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\threading.py", line 1049, in _wait_for_tstate_lock
#     elif lock.acquire(block, timeout):
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py", line 2061, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\inspect.py", line 1541, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\inspect.py", line 1499, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\inspect.py", line 709, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\inspect.py", line 752, in getmodule
#     f = getabsfile(module)
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\inspect.py", line 721, in getabsfile
#     _filename = getsourcefile(object) or getfile(object)
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\inspect.py", line 706, in getsourcefile
#     if os.path.exists(filename):
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\joblib\parallel.py", line 933, in retrieve
#     self._output.extend(job.get(timeout=self.timeout))
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\joblib\_parallel_backends.py", line 542, in wrap_future_result
#     return future.result(timeout=timeout)
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\concurrent\futures\_base.py", line 435, in result
#     self._condition.wait(timeout)
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\threading.py", line 312, in wait
#     waiter.acquire()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\magics\execution.py", line 1326, in time
#     out = eval(code_2, glob, local_ns)
#   File "<timed exec>", line 33, in <module>
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\sklearn\model_selection\_search.py", line 841, in fit
#     self._run_search(evaluate_candidates)
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\sklearn\model_selection\_search.py", line 1288, in _run_search
#     evaluate_candidates(ParameterGrid(self.param_grid))
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\sklearn\model_selection\_search.py", line 795, in evaluate_candidates
#     out = parallel(delayed(_fit_and_score)(clone(base_estimator),
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\joblib\parallel.py", line 1054, in __call__
#     self.retrieve()
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\joblib\parallel.py", line 955, in retrieve
#     backend.abort_everything(ensure_ready=ensure_ready)
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\joblib\_parallel_backends.py", line 561, in abort_everything
#     self._workers.terminate(kill_workers=True)
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\joblib\executor.py", line 74, in terminate
#     self.shutdown(kill_workers=kill_workers)
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\joblib\externals\loky\process_executor.py", line 1171, in shutdown
#     executor_manager_thread.join()
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\threading.py", line 1033, in join
#     self._wait_for_tstate_lock()
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\threading.py", line 1049, in _wait_for_tstate_lock
#     elif lock.acquire(block, timeout):
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py", line 2061, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-39-cbbc13c7fd5c>", line 1, in <module>
#     get_ipython().run_cell_magic('time', '', "import xgboost as xgb\nfrom sklearn.model_selection import GridSearchCV\n\nparameters = { \n                        'objective':['reg:linear'],\n                      'learning_rate': [0.3,0.2,0.1], \n                      'max_depth': [4,5,6],\n                      'min_child_weight': [1,2,3],\n                      'silent': [1],\n                      'subsample': [0.5,0.6,0.7],\n                      'colsample_bytree': [0.7,0.8,0.85],\n                      'n_estimators': [100,200,300]}\n# parameters = { \n#                     'objective':['reg:linear'],\n#                     'learning_rate': [0.3], \n#                     'max_depth': [4],\n#                     'min_child_weight': [1],\n#                     'silent': [1],\n#                     'subsample': [0.5],\n#                     'colsample_bytree': [0.7],\n#                     'n_estimators': [100]}\nxgb1 = xgb.XGBRegressor(verbosity=0) \n\n\nxgb_grid = GridSearchCV(xgb1,\n                        parameters,\n                        scoring='r2', #this line can be commented to use XGB's default metric\n                        cv = 5,\n                        n_jobs = 5,\n                        verbose=True)\n\n\nxgb_grid.fit(df_1,Y)\n")
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py", line 2399, in run_cell_magic
#     result = fn(*args, **kwargs)
#   File "<decorator-gen-55>", line 2, in time
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\magics\execution.py", line 1328, in time
#     self.shell.showtraceback()
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py", line 2063, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py", line 2061, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\inspect.py", line 1541, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\inspect.py", line 1499, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\inspect.py", line 709, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\inspect.py", line 755, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\ntpath.py", line 647, in realpath
#     path = _getfinalpathname(path)
# KeyboardInterrupt
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\joblib\parallel.py", line 933, in retrieve
#     self._output.extend(job.get(timeout=self.timeout))
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\joblib\_parallel_backends.py", line 542, in wrap_future_result
#     return future.result(timeout=timeout)
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\concurrent\futures\_base.py", line 435, in result
#     self._condition.wait(timeout)
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\threading.py", line 312, in wait
#     waiter.acquire()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\magics\execution.py", line 1326, in time
#     out = eval(code_2, glob, local_ns)
#   File "<timed exec>", line 33, in <module>
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\sklearn\model_selection\_search.py", line 841, in fit
#     self._run_search(evaluate_candidates)
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\sklearn\model_selection\_search.py", line 1288, in _run_search
#     evaluate_candidates(ParameterGrid(self.param_grid))
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\sklearn\model_selection\_search.py", line 795, in evaluate_candidates
#     out = parallel(delayed(_fit_and_score)(clone(base_estimator),
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\joblib\parallel.py", line 1054, in __call__
#     self.retrieve()
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\joblib\parallel.py", line 955, in retrieve
#     backend.abort_everything(ensure_ready=ensure_ready)
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\joblib\_parallel_backends.py", line 561, in abort_everything
#     self._workers.terminate(kill_workers=True)
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\joblib\executor.py", line 74, in terminate
#     self.shutdown(kill_workers=kill_workers)
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\joblib\externals\loky\process_executor.py", line 1171, in shutdown
#     executor_manager_thread.join()
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\threading.py", line 1033, in join
#     self._wait_for_tstate_lock()
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\threading.py", line 1049, in _wait_for_tstate_lock
#     elif lock.acquire(block, timeout):
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py", line 2061, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-39-cbbc13c7fd5c>", line 1, in <module>
#     get_ipython().run_cell_magic('time', '', "import xgboost as xgb\nfrom sklearn.model_selection import GridSearchCV\n\nparameters = { \n                        'objective':['reg:linear'],\n                      'learning_rate': [0.3,0.2,0.1], \n                      'max_depth': [4,5,6],\n                      'min_child_weight': [1,2,3],\n                      'silent': [1],\n                      'subsample': [0.5,0.6,0.7],\n                      'colsample_bytree': [0.7,0.8,0.85],\n                      'n_estimators': [100,200,300]}\n# parameters = { \n#                     'objective':['reg:linear'],\n#                     'learning_rate': [0.3], \n#                     'max_depth': [4],\n#                     'min_child_weight': [1],\n#                     'silent': [1],\n#                     'subsample': [0.5],\n#                     'colsample_bytree': [0.7],\n#                     'n_estimators': [100]}\nxgb1 = xgb.XGBRegressor(verbosity=0) \n\n\nxgb_grid = GridSearchCV(xgb1,\n                        parameters,\n                        scoring='r2', #this line can be commented to use XGB's default metric\n                        cv = 5,\n                        n_jobs = 5,\n                        verbose=True)\n\n\nxgb_grid.fit(df_1,Y)\n")
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py", line 2399, in run_cell_magic
#     result = fn(*args, **kwargs)
#   File "<decorator-gen-55>", line 2, in time
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\magics\execution.py", line 1328, in time
#     self.shell.showtraceback()
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py", line 2063, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py", line 2061, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py", line 3454, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py", line 2063, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py", line 2061, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\inspect.py", line 1541, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\inspect.py", line 1499, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\inspect.py", line 709, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\inspect.py", line 755, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "c:\users\администратор\appdata\local\programs\python\python39\lib\ntpath.py", line 647, in realpath
#     path = _getfinalpathname(path)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\joblib\parallel.py in retrieve(self)
#     932                 if getattr(self._backend, 'supports_timeout', False):
# --> 933                     self._output.extend(job.get(timeout=self.timeout))
#     934                 else:
#
# c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\joblib\_parallel_backends.py in wrap_future_result(future, timeout)
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#
# c:\users\администратор\appdata\local\programs\python\python39\lib\concurrent\futures\_base.py in result(self, timeout)
#     434
# --> 435             self._condition.wait(timeout)
#     436
#
# c:\users\администратор\appdata\local\programs\python\python39\lib\threading.py in wait(self, timeout)
#     311             if timeout is None:
# --> 312                 waiter.acquire()
#     313                 gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\magics\execution.py in time(self, line, cell, local_ns)
#    1325                     code_2 = self.shell.compile(expr_val, source, 'eval')
# -> 1326                     out = eval(code_2, glob, local_ns)
#    1327             except:
#
# <timed exec> in <module>
#
# c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#
# c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     840
# --> 841             self._run_search(evaluate_candidates)
#     842
#
# c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1287         """Search all candidates in param_grid"""
# -> 1288         evaluate_candidates(ParameterGrid(self.param_grid))
#    1289
#
# c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\sklearn\model_selection\_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     794
# --> 795                 out = parallel(delayed(_fit_and_score)(clone(base_estimator),
#     796                                                        X, y,
#
# c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1053             with self._backend.retrieval_context():
# -> 1054                 self.retrieve()
#    1055             # Make sure that we get a last message telling us we are done
#
# c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\joblib\parallel.py in retrieve(self)
#     954                     ensure_ready = self._managed_backend
# --> 955                     backend.abort_everything(ensure_ready=ensure_ready)
#     956                 raise
#
# c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\joblib\_parallel_backends.py in abort_everything(self, ensure_ready)
#     560         """
# --> 561         self._workers.terminate(kill_workers=True)
#     562         self._workers = None
#
# c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\joblib\executor.py in terminate(self, kill_workers)
#      73     def terminate(self, kill_workers=False):
# ---> 74         self.shutdown(kill_workers=kill_workers)
#      75         if kill_workers:
#
# c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\joblib\externals\loky\process_executor.py in shutdown(self, wait, kill_workers)
#    1170         if executor_manager_thread is not None and wait:
# -> 1171             executor_manager_thread.join()
#    1172
#
# c:\users\администратор\appdata\local\programs\python\python39\lib\threading.py in join(self, timeout)
#    1032         if timeout is None:
# -> 1033             self._wait_for_tstate_lock()
#    1034         else:
#
# c:\users\администратор\appdata\local\programs\python\python39\lib\threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1048             assert self._is_stopped
# -> 1049         elif lock.acquire(block, timeout):
#    1050             lock.release()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2060                         # in the engines. This should return a list of strings.
# -> 2061                         stb = value._render_traceback_()
#    2062                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-39-cbbc13c7fd5c> in <module>
# ----> 1 get_ipython().run_cell_magic('time', '', "import xgboost as xgb\nfrom sklearn.model_selection import GridSearchCV\n\nparameters = { \n                        'objective':['reg:linear'],\n                      'learning_rate': [0.3,0.2,0.1], \n                      'max_depth': [4,5,6],\n                      'min_child_weight': [1,2,3],\n                      'silent': [1],\n                      'subsample': [0.5,0.6,0.7],\n                      'colsample_bytree': [0.7,0.8,0.85],\n                      'n_estimators': [100,200,300]}\n# parameters = { \n#                     'objective':['reg:linear'],\n#                     'learning_rate': [0.3], \n#                     'max_depth': [4],\n#                     'min_child_weight': [1],\n#                     'silent': [1],\n#                     'subsample': [0.5],\n#                     'colsample_bytree': [0.7],\n#                     'n_estimators': [100]}\nxgb1 = xgb.XGBRegressor(verbosity=0) \n\n\nxgb_grid = GridSearchCV(xgb1,\n                        parameters,\n                        scoring='r2', #this line can be commented to use XGB's default metric\n                        cv = 5,\n                        n_jobs = 5,\n                        verbose=True)\n\n\nxgb_grid.fit(df_1,Y)\n")
#
# c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2398                 args = (magic_arg_s, cell)
# -> 2399                 result = fn(*args, **kwargs)
#    2400             return result
#
# <decorator-gen-55> in time(self, line, cell, local_ns)
#
# c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#
# c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\magics\execution.py in time(self, line, cell, local_ns)
#    1327             except:
# -> 1328                 self.shell.showtraceback()
#    1329                 return
#
# c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2062                     except Exception:
# -> 2063                         stb = self.InteractiveTB.structured_traceback(etype,
#    2064                                             value, tb, tb_offset=tb_offset)
#
# c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1366             self.tb = tb
# -> 1367         return FormattedTB.structured_traceback(
#    1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#
# c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1266             # Verbose modes need a full traceback
# -> 1267             return VerboseTB.structured_traceback(
#    1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#
# c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1123
# -> 1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1125                                                                tb_offset)
#
# c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#
# c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\ultratb.py in find_recursion(etype, value, records)
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2060                         # in the engines. This should return a list of strings.
# -> 2061                         stb = value._render_traceback_()
#    2062                     except Exception:
#
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py in run_ast_nodes(self, nodelist, cell_name, interactivity, compiler, result)
#    3356                         asy = compare(code)
# -> 3357                     if (await self.run_code(code, result,  async_=asy)):
#    3358                         return True
#
#     [... skipping hidden 1 frame]
#
# c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2062                     except Exception:
# -> 2063                         stb = self.InteractiveTB.structured_traceback(etype,
#    2064                                             value, tb, tb_offset=tb_offset)
#
# c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1366             self.tb = tb
# -> 1367         return FormattedTB.structured_traceback(
#    1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#
# c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1266             # Verbose modes need a full traceback
# -> 1267             return VerboseTB.structured_traceback(
#    1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#
# c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1123
# -> 1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1125                                                                tb_offset)
#
# c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#
# c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\ultratb.py in find_recursion(etype, value, records)
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2060                         # in the engines. This should return a list of strings.
# -> 2061                         stb = value._render_traceback_()
#    2062                     except Exception:
#
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\async_helpers.py in _pseudo_sync_runner(coro)
#      66     """
#      67     try:
# ---> 68         coro.send(None)
#      69     except StopIteration as exc:
#      70         return exc.value
#
# c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py in run_cell_async(self, raw_cell, store_history, silent, shell_futures, transformed_cell, preprocessing_exc_tuple)
#    3163                     interactivity = 'async'
#    3164
# -> 3165                 has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    3166                        interactivity=interactivity, compiler=compiler, result=result)
#    3167
#
# c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py in run_ast_nodes(self, nodelist, cell_name, interactivity, compiler, result)
#    3374             if result:
#    3375                 result.error_before_exec = sys.exc_info()[1]
# -> 3376             self.showtraceback()
#    3377             return True
#    3378
#
# c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2061                         stb = value._render_traceback_()
#    2062                     except Exception:
# -> 2063                         stb = self.InteractiveTB.structured_traceback(etype,
#    2064                                             value, tb, tb_offset=tb_offset)
#    2065
#
# c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1365         else:
#    1366             self.tb = tb
# -> 1367         return FormattedTB.structured_traceback(
#    1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369
#
# c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1265         if mode in self.verbose_modes:
#    1266             # Verbose modes need a full traceback
# -> 1267             return VerboseTB.structured_traceback(
#    1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1269             )
#
# c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1140         chained_exc_ids = set()
#    1141         while evalue:
# -> 1142             formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#    1143                                                                      chained_exceptions_tb_offset)
#    1144             exception = self.get_parts_of_chained_exception(evalue)
#
# c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1080
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#    1084         frames = self.format_records(records, last_unique, recursion_repeat)
#
# c:\users\администратор\appdata\local\programs\python\python39\lib\site-packages\IPython\core\ultratb.py in find_recursion(etype, value, records)
#     380     # first frame (from in to out) that looks different.
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#     384     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()

# %%
spike_cols = [col for col in dfg.columns if 'arage' in col]
print(list(df.columns))
print(spike_cols)
# Out:
# ['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC', 'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType', 'SaleCondition', 'SalePrice', 'LotAreaAdditional', 'YearReconstruction', '3rdFlrSF', 'Variable01', 'Variable02', 'Variable03', 'Variable04', 'Variable05']
# ['GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond']

# %%
dfg[['GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond']]
# Out:
#      GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 26          NaN          NaN          NaN           0           0        NaN
# 62          NaN          NaN          NaN           0           0        NaN
# 75          NaN          NaN          NaN           0           0        NaN
# 104         NaN          NaN          NaN           0           0        NaN
# 118         NaN          NaN          NaN           0           0        NaN
# 119         NaN          NaN          NaN           0           0        NaN
# 123         NaN          NaN          NaN           0           0        NaN
# 138         NaN          NaN          NaN           0           0        NaN
# 183         NaN          NaN          NaN           0           0        NaN
# 186         NaN          NaN          NaN           0           0        NaN
# 193         NaN          NaN          NaN           0           0        NaN
# 206         NaN          NaN          NaN           0           0        NaN
# 251         NaN          NaN          NaN           0           0        NaN
# 264         NaN          NaN          NaN           0           0        NaN
# 279         NaN          NaN          NaN           0           0        NaN
# 282         NaN          NaN          NaN           0           0        NaN
# 283         NaN          NaN          NaN           0           0        NaN
# 292         NaN          NaN          NaN           0           0        NaN
# 337         NaN          NaN          NaN           0           0        NaN
# 352         NaN          NaN          NaN           0           0        NaN
# 384         NaN          NaN          NaN           0           0        NaN
# 394         NaN          NaN          NaN           0           0        NaN
# 439         NaN          NaN          NaN           0           0        NaN
# 443         NaN          NaN          NaN           0           0        NaN
# 482         NaN          NaN          NaN           0           0        NaN
# 484         NaN          NaN          NaN           0           0        NaN
# 493         NaN          NaN          NaN           0           0        NaN
# 507         NaN          NaN          NaN           0           0        NaN
# 529         NaN          NaN          NaN           0           0        NaN
# 556         NaN          NaN          NaN           0           0        NaN
# 557         NaN          NaN          NaN           0           0        NaN
# 577         NaN          NaN          NaN           0           0        NaN
# 587         NaN          NaN          NaN           0           0        NaN
# 620         NaN          NaN          NaN           0           0        NaN
# 638         NaN          NaN          NaN           0           0        NaN
# 652         NaN          NaN          NaN           0           0        NaN
# 674         NaN          NaN          NaN           0           0        NaN
# 677         NaN          NaN          NaN           0           0        NaN
# 686         NaN          NaN          NaN           0           0        NaN
# 687         NaN          NaN          NaN           0           0        NaN
# 698         NaN          NaN          NaN           0           0        NaN
# 700         NaN          NaN          NaN           0           0        NaN
# 714         NaN          NaN          NaN           0           0        NaN
# 775         NaN          NaN          NaN           0           0        NaN
# 780         NaN          NaN          NaN           0           0        NaN
# 786         NaN          NaN          NaN           0           0        NaN
# 800         NaN          NaN          NaN           0           0        NaN
# 803         NaN          NaN          NaN           0           0        NaN
# 835         NaN          NaN          NaN           0           0        NaN
# 840         NaN          NaN          NaN           0           0        NaN
# 865         NaN          NaN          NaN           0           0        NaN
# 917         NaN          NaN          NaN           0           0        NaN
# 927         NaN          NaN          NaN           0           0        NaN
# 935         NaN          NaN          NaN           0           0        NaN
# 992         NaN          NaN          NaN           0           0        NaN
# 1026        NaN          NaN          NaN           0           0        NaN
# 1061        NaN          NaN          NaN           0           0        NaN
# 1063        NaN          NaN          NaN           0           0        NaN
# 1068        NaN          NaN          NaN           0           0        NaN
# 1104        NaN          NaN          NaN           0           0        NaN
# 1116        NaN          NaN          NaN           0           0        NaN
# 1142        NaN          NaN          NaN           0           0        NaN
# 1187        NaN          NaN          NaN           0           0        NaN
# 1200        NaN          NaN          NaN           0           0        NaN
# 1214        NaN          NaN          NaN           0           0        NaN
# 1228        NaN          NaN          NaN           0           0        NaN
#
#      GarageCond
# 26          NaN
# 62          NaN
# 75          NaN
# 104         NaN
# 118         NaN
# 119         NaN
# 123         NaN
# 138         NaN
# 183         NaN
# 186         NaN
# 193         NaN
# 206         NaN
# 251         NaN
# 264         NaN
# 279         NaN
# 282         NaN
# 283         NaN
# 292         NaN
# 337         NaN
# 352         NaN
# 384         NaN
# 394         NaN
# 439         NaN
# 443         NaN
# 482         NaN
# 484         NaN
# 493         NaN
# 507         NaN
# 529         NaN
# 556         NaN
# 557         NaN
# 577         NaN
# 587         NaN
# 620         NaN
# 638         NaN
# 652         NaN
# 674         NaN
# 677         NaN
# 686         NaN
# 687         NaN
# 698         NaN
# 700         NaN
# 714         NaN
# 775         NaN
# 780         NaN
# 786         NaN
# 800         NaN
# 803         NaN
# 835         NaN
# 840         NaN
# 865         NaN
# 917         NaN
# 927         NaN
# 935         NaN
# 992         NaN
# 1026        NaN
# 1061        NaN
# 1063        NaN
# 1068        NaN
# 1104        NaN
# 1116        NaN
# 1142        NaN
# 1187        NaN
# 1200        NaN
# 1214        NaN
# 1228        NaN

# %%
df_1['Variable04']=df['Variable04']

# %%
df_1.corr()['Variable04'].nlargest(10)
# Out:
# Variable04              1.000000
# ScreenPorch             0.075644
# Exterior2nd_Wd Sdng     0.073782
# Neighborhood_Veenker    0.069403
# BsmtFinType1_BLQ        0.068160
# BsmtCond_TA             0.065641
# GarageType_Attchd       0.058434
# FireplaceQu_Fa          0.058176
# HouseStyle_2.5Fin       0.056975
# Exterior2nd_AsphShn     0.053574
# Name: Variable04, dtype: float64

# %%
dfvar3=df_1.loc[df_1.Variable04.notna()]

# %%
dfvar3
y_var3=dfvar3.pop('Variable04')

# %%
X_trainv, X_testv, y_trainv, y_testv = train_test_split(dfvar3, y_var3, test_size=0.25, random_state=42)

# %%
regr = LinearRegression()
regr.fit(X_trainv, y_trainv)
from sklearn.metrics import r2_score
predictions=regr.predict(X_testv)
r2_score(y_testv,predictions)
# Out:
# -0.3694450819742734
